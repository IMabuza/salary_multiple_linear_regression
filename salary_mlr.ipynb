# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

df = pd.read_csv('salary.csv')

df = df.drop(['degree','otherqual','position','male','Field'], axis=1)

# Remove Nan values
df.dropna(how='any',axis=0)

df.shape

y = df.salary

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (411, 6)
# (103, 6)

# %% [markdown]
# #### Create scatterplots, histograms, and a descriptive statistics table of the variables of interest.

# %%
plt.hist(X_train['salary'],data=X_train, bins=20)

plt.show()

# %%
plt.subplot(2,3,1)

plt.scatter(X_train['salary'], X_train['exprior'], c="red")

plt.title("Salary vs Exprior")

plt.subplot(2,3,2)

plt.scatter(X_train['salary'], X_train['yearsworked'], c="green")

plt.title("Salary vs Years Worked")

plt.subplot(2,3,3)

plt.scatter(X_train['salary'], X_train['market'])

plt.title("Salary vs Market")

plt.subplot(2,3,4)

plt.scatter(X_train['salary'], X_train['yearsabs'], c="yellow")

plt.subplot(2,3,5)

plt.scatter(X_train['salary'], X_train['yearsrank'])

plt.show()

# %%
X_train.describe()
# Out:
#              salary     exprior  yearsworked   yearsrank      market  \
# count    411.000000  411.000000   411.000000  411.000000  411.000000
# mean   50859.967866    2.895377    12.905109    7.051095    0.944331
# std    12664.955266    4.652432     9.428718    6.390910    0.148223
# min    29500.000000    0.000000     0.000000    0.000000    0.710000
# 25%    40000.000000    0.000000     4.000000    2.000000    0.840000
# 50%    50008.000000    0.000000    12.000000    5.000000    0.910000
# 75%    60373.500000    4.000000    22.000000   12.000000    1.000000
# max    91405.000000   25.000000    41.000000   28.000000    1.330000
#
#          yearsabs
# count  411.000000
# mean     6.917275
# std     16.884340
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max    118.000000

# %% [markdown]
# #### Produce a correlation matrix comparing the relationship of salary to the predictor variables. Is there any multicollinearity or other problems that may be a problem in the multiple regression

# %%
X_train.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col0 {
#             background-color:  #b40426;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col1 {
#             background-color:  #96b7ff;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col2 {
#             background-color:  #f7ac8e;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col3 {
#             background-color:  #f5c2aa;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col4 {
#             background-color:  #d9dce1;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col5 {
#             background-color:  #536edd;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col0 {
#             background-color:  #7093f3;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col1 {
#             background-color:  #b40426;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col3 {
#             background-color:  #3d50c3;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col4 {
#             background-color:  #5a78e4;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col5 {
#             background-color:  #9abbff;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col0 {
#             background-color:  #f7ba9f;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col2 {
#             background-color:  #b40426;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col3 {
#             background-color:  #eb7d62;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col4 {
#             background-color:  #516ddb;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col5 {
#             background-color:  #7295f4;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col0 {
#             background-color:  #f5c1a9;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col1 {
#             background-color:  #6a8bef;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col2 {
#             background-color:  #e57058;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col3 {
#             background-color:  #b40426;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col4 {
#             background-color:  #5875e1;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col5 {
#             background-color:  #7295f4;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col0 {
#             background-color:  #cdd9ec;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col1 {
#             background-color:  #6a8bef;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col2 {
#             background-color:  #6180e9;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col4 {
#             background-color:  #b40426;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow5_col1 {
#             background-color:  #a6c4fe;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow5_col2 {
#             background-color:  #80a3fa;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow5_col3 {
#             background-color:  #5572df;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow5_col4 {
#             background-color:  #3b4cc0;
#         }    #T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow5_col5 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >salary</th>
#         <th class="col_heading level0 col1" >exprior</th>
#         <th class="col_heading level0 col2" >yearsworked</th>
#         <th class="col_heading level0 col3" >yearsrank</th>
#         <th class="col_heading level0 col4" >market</th>
#         <th class="col_heading level0 col5" >yearsabs</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806elevel0_row0" class="row_heading level0 row0" >salary</th>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col0" class="data row0 col0" >1</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col1" class="data row0 col1" >0.11</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col2" class="data row0 col2" >0.63</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col3" class="data row0 col3" >0.61</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col4" class="data row0 col4" >0.4</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow0_col5" class="data row0 col5" >-0.072</td>
#     </tr>    <tr>
#         <th id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806elevel0_row1" class="row_heading level0 row1" >exprior</th>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col0" class="data row1 col0" >0.11</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col1" class="data row1 col1" >1</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col2" class="data row1 col2" >-0.23</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col3" class="data row1 col3" >-0.044</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col4" class="data row1 col4" >-0.043</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow1_col5" class="data row1 col5" >0.17</td>
#     </tr>    <tr>
#         <th id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806elevel0_row2" class="row_heading level0 row2" >yearsworked</th>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col0" class="data row2 col0" >0.63</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col1" class="data row2 col1" >-0.23</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col2" class="data row2 col2" >1</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col3" class="data row2 col3" >0.8</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col4" class="data row2 col4" >-0.076</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow2_col5" class="data row2 col5" >0.036</td>
#     </tr>    <tr>
#         <th id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806elevel0_row3" class="row_heading level0 row3" >yearsrank</th>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col0" class="data row3 col0" >0.61</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col1" class="data row3 col1" >-0.044</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col2" class="data row3 col2" >0.8</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col3" class="data row3 col3" >1</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col4" class="data row3 col4" >-0.055</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow3_col5" class="data row3 col5" >0.039</td>
#     </tr>    <tr>
#         <th id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806elevel0_row4" class="row_heading level0 row4" >market</th>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col0" class="data row4 col0" >0.4</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col1" class="data row4 col1" >-0.043</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col2" class="data row4 col2" >-0.076</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col3" class="data row4 col3" >-0.055</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col4" class="data row4 col4" >1</td>
#         <td id="T_2051ae8c_70a7_11e9_9f7c_2b13f46d806erow4_col5" class="data row4 col5" >-0.16</td>
#     </tr>    <tr>
#         <th id="T_2051ae8c_70a7_11e9_9f

# %% [markdown]
# #### No multicollinearity

# %%
X_train.head()
# Out:
#           salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 320  80137.00000        5           21         20    1.04       1          0
# 329  39777.00000       10           17         10    0.86       1          0
# 173  61453.00000        0           15          0    1.21       1          0
# 272  53665.00000        0           25         12    0.92       1          0
# 493  44410.85547        7           12         10    0.72       1          0
#
#      position  male  Field  yearsabs
# 320         3     1      2         0
# 329         2     1      3         1
# 173         2     1      1         0
# 272         3     1      1         0
# 493         2     0      3        51
